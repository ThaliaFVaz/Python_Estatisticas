# %%
import random
import pandas as pd
import numpy as np
import plotly.express as px
import pandas as pd
import math
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Séries temporais/quase senoidal.csv') 
df.head(20)
# Out:
#           data  valor
# 0   2021-01-01    NaN
# 1   2021-01-02    NaN
# 2   2021-01-03  13.94
# 3   2021-01-04  15.66
# 4   2021-01-05  17.25
# 5   2021-01-06  18.56
# 6   2021-01-07  19.42
# 7   2021-01-08  19.99
# 8   2021-01-09  20.05
# 9   2021-01-10  19.87
# 10  2021-01-11  19.17
# 11  2021-01-12    NaN
# 12  2021-01-13  16.83
# 13  2021-01-14  15.35
# 14  2021-01-15  13.70
# 15  2021-01-16  11.66
# 16  2021-01-17   9.61
# 17  2021-01-18   7.63
# 18  2021-01-19   6.04
# 19  2021-01-20   3.96

# %%
#plota o sinal original

df.plot(x ='data', y=['valor'], figsize=(10, 5), kind = 'line', title="sinal original")
plt.show()

# %%
#aplica alguma interpolação,  #backforwad: aplicar esse
df = df.ffill()

# %%
#plota o sinal com a interpolação aplicada

df.plot(x ='data', y=['valor'], figsize=(10, 5), kind = 'line', title="sinal interpolado")
plt.show()
